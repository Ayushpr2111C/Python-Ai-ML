# %%
import pandas as pd

# %%
df = pd.read_csv("OnePieceArcs.csv")
df.head()
# Out:
#                  Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 0   Romance Dawn Arc                1              7         178   0.9%
# 1    Orange Town Arc                8             14         273   1.4%
# 2  Syrup Village Arc               22             20         396   2.0%
# 3        Baratie Arc               42             27         514   2.6%
# 4    Arlong Park Arc               69             27         514   2.6%
#
#    Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 0                1              3                    72   0.3%
# 1                4              5                   120   0.5%
# 2                9             10                   240   1.0%
# 3               19             12                   288   1.2%
# 4               31             15                   360   1.5%

# %%
df.head()
# Out:
#                  Arc  Start onChapter  TotalChapters  TotalPages Manga%  \
# 0   Romance Dawn Arc                1              7         178   0.9%
# 1    Orange Town Arc                8             14         273   1.4%
# 2  Syrup Village Arc               22             20         396   2.0%
# 3        Baratie Arc               42             27         514   2.6%
# 4    Arlong Park Arc               69             27         514   2.6%
#
#    Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# 0                1              3                    72   0.3%
# 1                4              5                   120   0.5%
# 2                9             10                   240   1.0%
# 3               19             12                   288   1.2%
# 4               31             15                   360   1.5%

# %%
df.set_index("Arc", inplace=True)
df.head()
# Out:
#                    Start onChapter  TotalChapters  TotalPages Manga%  \
# Arc
# Romance Dawn Arc                 1              7         178   0.9%
# Orange Town Arc                  8             14         273   1.4%
# Syrup Village Arc               22             20         396   2.0%
# Baratie Arc                     42             27         514   2.6%
# Arlong Park Arc                 69             27         514   2.6%
#
#                    Start onEpisode  TotalEpisodes  TotalMinutes(avg 24) Anime%
# Arc
# Romance Dawn Arc                 1              3                    72   0.3%
# Orange Town Arc                  4              5                   120   0.5%
# Syrup Village Arc                9             10                   240   1.0%
# Baratie Arc                     19             12                   288   1.2%
# Arlong Park Arc                 31             15                   360   1.5%
