# %% [markdown]
# - Different methods to create a data set.
# - Reading database from external sources.
# - Basic insight of dataset
# - selection daughter
#     - row wise selection,
#     - column of selection
# - Data cleaning and manipulation.
