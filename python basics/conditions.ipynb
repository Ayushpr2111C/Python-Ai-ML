# %%
age = int(input("enter your age: "))
if age >= 18:
    print("you are eligible for dl")
else:
    print("you are not eligible for dl")

# %%
a=int (input("enter a number: ")   )
if a%2==0:
    print("even")
else:
    print("odd")

# %%
num1 = int(input("enter first number: "))

if num1 > 0:
    print("positive")
elif num1 < 0:
    print("negative")   
else:
    print("zero")

# %%
num1 = int(input("enter first number: "))

if num1 <= 100 and num1 >= 90:
    print(" Your grade is A")
elif num1 < 90 and num1 >= 70:
    print(" Your grade is B")
elif num1 < 70 and num1 >= 50:
    print(" Your grade is C")
elif num1 < 50 and num1 >= 0:
    print(" Fail")
else:
    print(" Invalid input")

# %%
num1 = int(input("enter first number: "))
num2 = int(input("enter second number: "))  
num3 = int(input("enter third number: "))
if num1 >= num2 and num1 >= num3:
    print("largest number is: ", num1)
elif num2 >= num1 and num2 >= num3:
    print("largest number is: ", num2)
else:
    print("largest number is: ", num3)

# %%
num1 = int(input("enter first number: "))
num2 = int(input("enter second number: "))
num3 = int(input("enter third number: "))
if num1==num2 and num2==num3:
    print("The triangle is equilateral")
elif num1==num2 or num2==num3 or num1==num3:
    print("The triangle is isosceles")
else:
    print("The triangle is scalene")

# %%
pr= int(input("enter the price: "))
if pr>1000 and pr<=4000:
    a= pr*0.1
    pr1= pr-a
    print("the price after discount is: ", pr1)
    print("the discount is: ", a)

elif pr>4000 and pr<=6000:
    a=pr*0.15
    pr1= pr-a
    print("the price after discount is: ", pr1)
    print("the discount is: ", a)

elif pr>6000:
    a=pr*0.2
    pr1= pr-a
    print("the price after discount is: ", pr1)
    print("the discount is: ", a)

else:
    print("no discount")

# %%
angl1 = int(input("enter first angle: "))

if angl1 == 90:
    print("The Angle is right angled")
elif angl1 > 90:
    print("The Angle is obtuse angled")
else:
    print("The Angle is acute angled")

# %%
age = int(input("enter your age: "))
income = int(input("enter your income: "))
credit_score = int(input("enter your credit score: "))

if age >= 18 and income >= 50000 and credit_score >= 700:
    print("You are eligible for the loan.")
else:
    print("You are not eligible for the loan.")
# Out:
# You are not eligible for the loan.

# %%
username = input("enter your username: ")
email = input("enter your email: ")
password = input("enter your password: ")
confirm_password = input("confirm your password: ")
if len(username) <= 5 and len(password) >= 15:
    print("Username should be at least 5 characters long.")
    print("Password should be at least 15 characters long.")

else:
    print(f"Username: {username}")
    if '@' not in email:
        print("Invalid email address.")
    else:
        print(f"Email: {email}")
        if len(password) <= 15 and len(password) >= 8:
            if password != confirm_password:
                print("Passwords do not match.")
            else:
                print(f"Password: {password}")
                print("Registration successful.")
        else:
            print("Password should be between 8 and 15 characters long.")
# Out:
# Username: Ayushpr2111C
# Email: ayushpr2111c@gmail.com
# Password: Ayushpr2111C
# Registration successful.

# %%
usermame = input("enter your username: ")
email = input("enter your email: ")
password = input("enter your password: ")
confirm_password = input("confirm your password: ")
if len(username) >= 5 and len(password) <= 15:
    print (f"Username: {username}")
    if '@' in email:
        print("valid email address.")
        print(f"Email: {email}")
        if len(password) >= 8 and len(password) <= 15:
            if password == confirm_password:
                print(f"Password: {password}")
                print("Registration successful.")
            else:
                print("Passwords do not match.")
        else:
            print("Password should be between 8 and 15 characters long.")
    else:
        print("Invalid email address.")
else:
    print("Username should be at least 5 characters long.")
    print("Password should be at least 15 characters long.")
