# %%
# %pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.51-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.5.3-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Users\abhis\miniconda3\Lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.51-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 253.1 kB/s eta 0:00:07
#    --------- ------------------------------ 0.5/2.1 MB 253.1 kB/s eta 0:00:07
#    --------- ------------------------------ 0.5/2.1 MB 253.1 kB/s eta 0:00:07
#    -------------- ------------------------- 0.8/2.1 MB 313.5 kB/s eta 0:00:05
#    -------------- ------------------------- 0.8/2.1 MB 313.5 kB/s eta 0:00:05
#    -------------- ------------------------- 0.8/2.1 MB 313.5 kB/s eta 0:00:05
#    ------------------- -------------------- 1.0/2.1 MB 348.4 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.1 MB 348.4 kB/s eta 0:00:04
#    ------------------------ --------------- 1.3/2.1 MB 375.8 kB/s eta 0:00:03
#    ------------------------ --------------- 1.3/2.1 MB 375.8 kB/s eta 0:00:03
#    ------------------------ --------------- 1.3/2.1 MB 375.8 kB/s eta 0:00:03
#    ----------------------------- ---------- 1.6/2.1 MB 394.7 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.6/2.1 MB 394.7 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.6/2.1 MB 394.7 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 392.9 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 294.2 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 294.2 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 283.9 kB/s  0:00:07
# Downloading greenlet-3.5.3-cp313-cp313-win_amd64.whl (239 kB)
# Installing collected packages: greenlet, sqlalchemy
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    ---------------------------------------- 2/2 [sqlalchemy]
#
# Successfully installed greenlet-3.5.3 sqlalchemy-2.0.51
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/sqlalchemy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/sqlalchemy/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/sqlalchemy/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/sqlalchemy/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/sqlalchemy/

# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
engine = create_engine('sqlite:///database.db')
Base = declarative_base()
class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    email = Column(String)
    password = Column(String)

    def __repr__(self):
        return "<User(name='%s', fullname='%s', nickname='%s')>" % (
            self.name, self.fullname, self.nickname)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_8380\1748733519.py:2: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

# %%
new_user = User(name="Abhishek", email="9t6tM@example.com", password="1234")
session.add(new_user)
session.commit()

# %%
Users = session.query(User).all()
for user in Users:
    print(user.name)   
    print(user.email)
    print(user.password)
# Out:
# Abhishek
# 9t6tM@example.com
# 1234

# %%
user = session.query(User).filter_by(email="9t6tM@example.com").first()
user.password = "12345"
session.commit()
