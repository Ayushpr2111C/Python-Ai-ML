# %%
poem='''Johny Johny Yes Papa
Eating Sugar No Papa
Telling Lies No Papa
Open Your Mouth Ha Ha Ha'''
print(poem)
# Out:
# Johny Johny Yes Papa
# Eating Sugar No Papa
# Telling Lies No Papa
# Open Your Mouth Ha Ha Ha

# %%
poem.find("Johny")
# Out:
# 0

# %%
print(poem.replace("papa", "fufa").replace("sugar", "poison").replace("eating", "drinking"))
# Out:
# Johny Johny Yes Papa
# Eating Sugar No Papa
# Telling Lies No Papa
# Open Your Mouth Ha Ha Ha

# %%
print(poem.index("Papa"))
print(poem.find("Papa"))
print(poem.find("a"))
# Out:
# 16
# 16
# 17
