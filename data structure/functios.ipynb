# %% [markdown]
# `FUNCTION`: a block of code to ruse any functionality
# `types of functions`:
# - user definred functions:
#     - parameterised functions
#     - non paremeterised functions
#     - return functions
#     - non return functions
#     - default parameterised functions
#     - lamba functions
# - built in funtions:
#     - append, len etc

# %%
def greet():
    print('''Hello User
Welcome to my first func
Have a nice day
          ''')
greet()
# Out:
# Hello User
# Welcome to my first func
# Have a nice day

# %%
def sum(x,y):
    print(x+y)
sum(6,8)
# Out:
# 14

# %%
def sum(x,y):
    return x+y
re=sum(9,3)
re/2
# Out:
# 6.0

# %%
def myc(c="India"):
    print(f"I love {c}")
    
myc("USA")
# Out:
# I love USA

# %%
def sq(n):
    return n**2
print(sq(3))
# Out:
# 9

# %%
lsq= lambda x:x**2 #arg:exp
lsq(3)
# Out:
# 9

# %%
eo= lambda n:"Even" if n%2==0 else "Odd"

# %%
lst=[]
while True:
    s = input("Enter your number and hit enter for the next number (enter 'x' and hit enter to stop): ")
    if s == "x":
        break
    lst.append(int(s))
    
lst
# Out:
# [8, 9, 6]

# %%
lst= [4,5,7,8,9,6]
nlst=[]
for i in lst:
    nlst.append(i)   
nlst
# Out:
# [4, 5, 7, 8, 9, 6]

# %% [markdown]
# map and filter

# %%
pallindrom= lambda s: s==s[::-1]
pallindrom("lav")
# Out:
# False

# %%
ns=[1,2,3,6,5,4,7,8,9]
en= list(filter(lambda x:x%2==0, ns))
en
# Out:
# [2, 6, 4, 8]
