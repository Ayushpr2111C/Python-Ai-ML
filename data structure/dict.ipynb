# %%
a={
    "lucknow":[26,32,36] ,
    "Chennai" : [36,26,32],
    "Delhi": [26,32,36]
    }
print(a)
# Out:
# {'lucknow': [26, 32, 36], 'Chennai': [36, 26, 32], 'Delhi': [26, 32, 36]}

# %%
info= dict(name='Ayush', age='19', cource='CSE')
print(info)
# Out:
# {'name': 'Ayush', 'age': '19', 'cource': 'CSE'}

# %% [markdown]
# to access values using key

# %%
print(a['lucknow'])
a.get('lucknow')
# Out:
# [26, 32, 36]
# [26, 32, 36]

# %%
print(a.values())
print(a.keys())
print(a.items())
# Out:
# dict_values([[26, 32, 36], [36, 26, 32], [26, 32, 36]])
# dict_keys(['lucknow', 'Chennai', 'Delhi'])
# dict_items([('lucknow', [26, 32, 36]), ('Chennai', [36, 26, 32]), ('Delhi', [26, 32, 36])])

# %%
for i in a:
    print(i)
    print(a[i])
# Out:
# lucknow
# [26, 32, 36]
# Chennai
# [36, 26, 32]
# Delhi
# [26, 32, 36]

# %%
for i,j in a.items():
    print(i,j)
# Out:
# lucknow [26, 32, 36]
# Chennai [36, 26, 32]
# Delhi [26, 32, 36]

# %%
a['patial','suratgarh']=[36,34,38],[34,32,38]
print(a)
# Out:
# {'lucknow': [26, 32, 36], 'Chennai': [36, 26, 32], 'Delhi': [26, 32, 36], 'jodhpur': [36, 34, 38], ('patial', 'suratgarh'): ([36, 34, 38], [34, 32, 38])}

# %%
company={
    "emp1":{
        "name":"Ayush",
        "dept":"ceo",
        "salary":1500000
    },
    "emp2":{
        "name":"mamta",
        "dept":"co-founder",
        "salary":2000000
    }
}
print(company)
# Out:
# {'emp1': {'name': 'Ayush', 'dept': 'ceo', 'salary': 1500000}, 'emp2': {'name': 'mamta', 'dept': 'co-founder', 'salary': 2000000}}

# %% [markdown]
# PRINT THE AVERAGE TEMP OF LUCKNOW IN TEMP DICT

# %%
temp={
    "lucknow":[26,32,36] ,
    "Chennai" : [36,26,32],
    "Delhi": [26,32,36]
    }
total_temp=0
no_of_entries=len(a["lucknow"])
for i in temp["lucknow"]:
        total_temp+=i


e=sum(temp["lucknow"])/no_of_entries


d=total_temp/no_of_entries
print(d, e)
# Out:
# 31.333333333333332 31.333333333333332
